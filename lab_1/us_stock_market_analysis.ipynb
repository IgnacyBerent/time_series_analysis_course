# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7696\2151744951.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('USStockMarketDataset.csv', parse_dates=[1], index_col=0)
# convert all dates to one format - if date is in format dd/mm/yyyy convert it to dd-mm-yyyy
df['Date'] = df['Date'].str.replace('/', '-')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
# convert all price columns to float, if there is a comma in the number, remove it
price_columns = df.columns.str.contains('Price')
df.loc[:, price_columns] = df.loc[:, price_columns].replace(',', '', regex=True).astype(float)
df.head()
# Out:
#         Date  Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# 0 2024-02-02              2.079               NaN            72.28
# 1 2024-02-01              2.050          161340.0            73.82
# 2 2024-01-31              2.100          142860.0            75.85
# 3 2024-01-30              2.077          139750.0            77.82
# 4 2024-01-29              2.490            3590.0            76.78
#
#    Crude_oil_Vol.  Copper_Price  Copper_Vol. Bitcoin_Price  Bitcoin_Vol.  \
# 0             NaN        3.8215          NaN       43194.7         42650
# 1        577940.0        3.8535          NaN       43081.4         47690
# 2        344490.0        3.9060          NaN       42580.5         56480
# 3        347240.0        3.9110          NaN       42946.2         55130
# 4        331930.0        3.8790          NaN       43299.8         45230
#
#   Platinum_Price  ...  Berkshire_Price Berkshire_Vol.  Netflix_Price  \
# 0          901.6  ...         589498.0          10580         564.64
# 1          922.3  ...         581600.0           9780         567.51
# 2          932.6  ...         578020.0           9720         564.11
# 3          931.7  ...         584680.0           9750         562.85
# 4          938.3  ...         578800.0          13850         575.79
#
#   Netflix_Vol. Amazon_Price  Amazon_Vol.  Meta_Price  Meta_Vol.  Gold_Price  \
# 0      4030000       171.81    117220000      474.99   84710000      2053.7
# 1      3150000       159.28     66360000      394.78   25140000      2071.1
# 2      4830000       155.20     49690000      390.14   20010000      2067.4
# 3      6120000       159.00     42290000      400.06   18610000      2050.9
# 4      6880000       161.26     42840000      401.02   17790000      2034.9
#
#    Gold_Vol.
# 0        NaN
# 1   260920.0
# 2   238370.0
# 3   214590.0
# 4     1780.0
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1013 entries, 0 to 1012
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1013 non-null   datetime64[ns]
#  1   Natural_Gas_Price  1013 non-null   float64
#  2   Natural_Gas_Vol.   1009 non-null   float64
#  3   Crude_oil_Price    1013 non-null   float64
#  4   Crude_oil_Vol.     990 non-null    float64
#  5   Copper_Price       1013 non-null   float64
#  6   Copper_Vol.        976 non-null    float64
#  7   Bitcoin_Price      1013 non-null   object
#  8   Bitcoin_Vol.       1013 non-null   int64
#  9   Platinum_Price     1013 non-null   object
#  10  Platinum_Vol.      636 non-null    float64
#  11  Ethereum_Price     1013 non-null   object
#  12  Ethereum_Vol.      1013 non-null   int64
#  13  S&P_500_Price      1013 non-null   object
#  14  Nasdaq_100_Price   1013 non-null   object
#  15  Nasdaq_100_Vol.    1012 non-null   float64
#  16  Apple_Price        1013 non-null   float64
#  17  Apple_Vol.         1013 non-null   int64
#  18  Tesla_Price        1013 non-null   float64
#  19  Tesla_Vol.         1013 non-null   int64
#  20  Microsoft_Price    1013 non-null   float64
#  21  Microsoft_Vol.     1013 non-null   int64
#  22  Silver_Price       1013 non-null   float64
#  23  Silver_Vol.        967 non-null    float64
#  24  Google_Price       1013 non-null   float64
#  25  Google_Vol.        1013 non-null   int64
#  26  Nvidia_Price       1013 non-null   float64
#  27  Nvidia_Vol.        1013 non-null   int64
#  28  Berkshire_Price    1013 non-null   object
#  29  Berkshire_Vol.     1013 non-null   int64
#  30  Netflix_Price      1013 non-null   float64
#  31  Netflix_Vol.       1013 non-null   int64
#  32  Amazon_Price       1013 non-null   float64
#  33  Amazon_Vol.        1013 non-null   int64
#  34  Meta_Price         1013 non-null   float64
#  35  Meta_Vol.          1013 non-null   int64
#  36  Gold_Price         1013 non-null   object
#  37  Gold_Vol.          1011 non-null   float64
# dtypes: datetime64[ns](1), float64(19), int64(11), object(7)
# memory usage: 308.6+ KB

# %%
df_prices = df[df.columns[df.columns.str.contains('Price')]]
df_prices['Date'] = df['Date']
# make Date column a first column
cols = df_prices.columns.tolist()
cols = cols[-1:] + cols[:-1]
df_prices = df_prices[cols]
df_prices.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7696\1133227026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prices['Date'] = df['Date']
#         Date  Natural_Gas_Price  Crude_oil_Price  Copper_Price Bitcoin_Price  \
# 0 2024-02-02              2.079            72.28        3.8215       43194.7
# 1 2024-02-01              2.050            73.82        3.8535       43081.4
# 2 2024-01-31              2.100            75.85        3.9060       42580.5
# 3 2024-01-30              2.077            77.82        3.9110       42946.2
# 4 2024-01-29              2.490            76.78        3.8790       43299.8
#
#   Platinum_Price Ethereum_Price S&P_500_Price Nasdaq_100_Price  Apple_Price  \
# 0          901.6        2309.28       4958.61         17642.73       185.85
# 1          922.3        2304.28       4906.19         17344.71       186.86
# 2          932.6        2283.14       4848.87         17137.24       184.40
# 3          931.7        2343.11       4924.97         17476.71       188.04
# 4          938.3        2317.79       4927.93         17596.27       191.73
#
#    Tesla_Price  Microsoft_Price  Silver_Price  Google_Price  Nvidia_Price  \
# 0       187.91           411.22        22.796        142.38        661.60
# 1       188.86           403.78        23.236        141.16        630.27
# 2       187.29           397.58        23.169        140.10        615.27
# 3       191.59           408.59        23.225        151.46        627.74
# 4       190.93           409.72        23.134        153.51        624.65
#
#   Berkshire_Price  Netflix_Price  Amazon_Price  Meta_Price Gold_Price
# 0        589498.0         564.64        171.81      474.99     2053.7
# 1        581600.0         567.51        159.28      394.78     2071.1
# 2        578020.0         564.11        155.20      390.14     2067.4
# 3        584680.0         562.85        159.00      400.06     2050.9
# 4        578800.0         575.79        161.26      401.02     2034.9

# %%
# show null values in the columns
df_prices.isnull().sum()
# Out:
# Date                 0
# Natural_Gas_Price    0
# Crude_oil_Price      0
# Copper_Price         0
# Bitcoin_Price        0
# Platinum_Price       0
# Ethereum_Price       0
# S&P_500_Price        0
# Nasdaq_100_Price     0
# Apple_Price          0
# Tesla_Price          0
# Microsoft_Price      0
# Silver_Price         0
# Google_Price         0
# Nvidia_Price         0
# Berkshire_Price      0
# Netflix_Price        0
# Amazon_Price         0
# Meta_Price           0
# Gold_Price           0
# dtype: int64

# %%
df_prices.describe()
# Out:
#                                 Date  Natural_Gas_Price  Crude_oil_Price  \
# count                           1013        1013.000000      1013.000000
# mean   2022-01-18 19:55:29.911154944           3.726667        69.853475
# min              2020-01-02 00:00:00           1.482000       -37.630000
# 25%              2021-01-08 00:00:00           2.447000        54.760000
# 50%              2022-01-20 00:00:00           2.880000        72.910000
# 75%              2023-01-31 00:00:00           4.805000        82.810000
# max              2024-02-02 00:00:00           9.647000       123.700000
# std                              NaN           1.943030        21.986697
#
#        Copper_Price  Apple_Price  Tesla_Price  Microsoft_Price  Silver_Price  \
# count   1013.000000  1013.000000  1013.000000      1013.000000   1013.000000
# mean       3.726843   141.964462   208.928263       265.838855     22.795356
# min        2.100500    56.090000    24.080000       135.420000     11.772000
# 25%        3.408000   124.610000   160.950000       223.290000     21.327000
# 50%        3.800500   146.500000   222.640000       260.790000     23.383000
# 75%        4.251500   168.640000   261.160000       308.650000     24.949000
# max        4.937500   198.110000   409.970000       411.220000     29.418000
# std        0.646524    33.778785    84.917541        57.493641      3.170649
#
#        Google_Price  Nvidia_Price  Netflix_Price  Amazon_Price   Meta_Price
# count   1013.000000   1013.000000    1013.000000   1013.000000  1013.000000
# mean     108.659882    219.738065     422.035479    137.426209   252.151046
# min       52.710000     49.100000     166.370000     81.820000    88.910000
# 25%       88.130000    131.980000     338.630000    114.770000   195.210000
# 50%      111.450000    179.130000     431.600000    142.300000   262.010000
# 75%      131.910000    272.470000     509.640000    161.060000   313.190000
# max      153.510000    661.600000     691.690000    186.570000   474.990000
# std       25.438302    128.668703     119.765870     27.321896    72.949246

# %%
plt.figure(figsize=(12, 8))
max_price = 0
for c in df_prices.columns:
    if c != 'Date':
        plt.plot(df_prices['Date'], df_prices[c], label=c)
        max_price = max(max_price, df_prices[c].max())
plt.title('Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.yticks(np.arange(0, max_price+1000, 10))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 plt.xlabel('Date')
#       9 plt.ylabel('Price')
# ---> 10 plt.yticks(np.arange(0, max_price+1000, 10))
#      11 plt.legend()
#      12 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:2116, in yticks(ticks, labels, minor, **kwargs)
#    2113         raise TypeError("yticks(): Parameter 'labels' can't be set "
#    2114                         "without setting 'ticks'")
#    2115 else:
# -> 2116     locs = ax.set_yticks(ticks, minor=minor)
#    2118 labels_out: list[Text] = []
#    2119 if labels is None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:2138, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2133     first_key = next(iter(kwargs))
#    2134     raise ValueError(
#    2135         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2136         "other than 'minor' modify the text labels and can only be used if "
#    2137         "'labels' are passed as well.")
# -> 2138 result = self._set_tick_locations(ticks, minor=minor)
#    2139 if labels is not None:
#    2140     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:2089, in Axis._set_tick_locations(self, ticks, minor)
#    2087 else:
#    2088     self.set_major_locator(locator)
# -> 2089     return self.get_major_ticks(len(ticks))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:1626, in Axis.get_major_ticks(self, numticks)
#    1622     numticks = len(self.get_majorticklocs())
#    1624 while len(self.majorTicks) < numticks:
#    1625     # Update the new tick label properties from the old.
# -> 1626     tick = self._get_tick(major=True)
#    1627     self.majorTicks.append(tick)
#    1628     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:1562, in Axis._get_tick(self, major)
#    1558     raise NotImplementedError(
#    1559         f"The Axis subclass {self.__class__.__name__} must define "
#    1560         "_tick_class or reimplement _get_tick()")
#    1561 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1562 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:470, in YTick.__init__(self, *args, **kwargs)
#     469 def __init__(self, *args, **kwargs):
# --> 470     super().__init__(*args, **kwargs)
#     471     # x in axes coords, y in data coords
#     472     ax = self.axes
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:187, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     178 self.label1 = mtext.Text(
#     179     np.nan, np.nan,
#     180     fontsize=labelsize, color=labelcolor, visible=label1On,
#     181     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#     182 self.label2 = mtext.Text(
#     183     np.nan, np.nan,
#     184     fontsize=labelsize, color=labelcolor, visible=label2On,
#     185     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
# --> 187 self._apply_tickdir(tickdir)
#     189 for artist in [self.tick1line, self.tick2line, self.gridline,
#     190                self.label1, self.label2]:
#     191     self._set_artist_props(artist)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:505, in YTick._apply_tickdir(self, tickdir)
#     499 super()._apply_tickdir(tickdir)
#     500 mark1, mark2 = {
#     501     'out': (mlines.TICKLEFT, mlines.TICKRIGHT),
#     502     'in': (mlines.TICKRIGHT, mlines.TICKLEFT),
#     503     'inout': ('_', '_'),
#     504 }[self._tickdir]
# --> 505 self.tick1line.set_marker(mark1)
#     506 self.tick2line.set_marker(mark2)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\lines.py:1194, in Line2D.set_marker(self, marker)
#    1183 @_docstring.interpd
#    1184 def set_marker(self, marker):
#    1185     """
#    1186     Set the line marker.
#    1187
#    (...)
#    1192         arguments.
#    1193     """
# -> 1194     self._marker = MarkerStyle(marker, self._marker.get_fillstyle())
#    1195     self.stale = True
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\markers.py:255, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     253 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     254 self._set_fillstyle(fillstyle)
# --> 255 self._set_marker(marker)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\markers.py:343, in MarkerStyle._set_marker(self, marker)
#     341 if not isinstance(marker, MarkerStyle):
#     342     self._marker = marker
# --> 343     self._recache()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\markers.py:271, in MarkerStyle._recache(self)
#     267 # Initial guess: Assume the marker is filled unless the fillstyle is
#     268 # set to 'none'. The marker function will override this for unfilled
#     269 # markers.
#     270 self._filled = self._fillstyle != 'none'
# --> 271 self._marker_function()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\markers.py:766, in MarkerStyle._set_tickleft(self)
#     765 def _set_tickleft(self):
# --> 766     self._transform = Affine2D().scale(-1.0, 1.0)
#     767     self._snap_threshold = 1.0
#     768     self._filled = False
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\transforms.py:1903, in Affine2D.__init__(self, matrix, **kwargs)
#    1900 if matrix is None:
#    1901     # A bit faster than np.identity(3).
#    1902     matrix = IdentityTransform._mtx
# -> 1903 self._mtx = matrix.copy()
#    1904 self._invalid = 0
#
# KeyboardInterrupt:
